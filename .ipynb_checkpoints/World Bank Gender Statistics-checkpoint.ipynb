# %% [markdown]
# Questions:
# - How does gender equality in terms of education and employment look around the world?
# - Is there any pattern among low income and high income countries for gender equality?
# - Does increased government spending on education have an impact on female literacy rate?

# %%
#Importing required libraries
import numpy as np
import pandas as pd

# %%
#Reading the first dataset
country = pd.read_csv('Gender_Stats_csv/Gender_StatsCountry.csv')
country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit Special Notes                     Region  \
# 0           AW   Aruban florin           NaN  Latin America & Caribbean
# 1           AF  Afghan afghani           NaN                 South Asia
# 2           AO  Angolan kwanza           NaN         Sub-Saharan Africa
# 3           AL    Albanian lek           NaN      Europe & Central Asia
# 4           AD            Euro           NaN      Europe & Central Asia
#
#           Income Group WB-2 code     ...        Government Accounting concept  \
# ...

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 31 columns):
# Country Code                                         263 non-null object
# Short Name                                           263 non-null object
# Table Name                                           263 non-null object
# Long Name                                            263 non-null object
# 2-alpha code                                         261 non-null object
# Currency Unit                                        217 non-null object
# Special Notes                                        94 non-null object
# Region                                               217 non-null object
# Income Group                                         217 non-null object
# WB-2 code                                            262 non-null object
# National accounts base year                          210 non-null object
# ...

# %%
#Dropping the non-required columns
country = country[['Country Code','Short Name','Region','Income Group']]
country.head()
# Out:
#   Country Code   Short Name                     Region         Income Group
# 0          ABW        Aruba  Latin America & Caribbean          High income
# 1          AFG  Afghanistan                 South Asia           Low income
# 2          AGO       Angola         Sub-Saharan Africa  Lower middle income
# 3          ALB      Albania      Europe & Central Asia  Upper middle income
# 4          AND      Andorra      Europe & Central Asia          High income

# %%
#Reading the second dataset
stats = pd.read_csv('Gender_Stats_csv/Gender_StatsData.csv')
stats.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ   NaN
# 1  A woman can be head of household in the same w...  SG.HLD.HEAD.EQ   NaN
# 2  A woman can choose where to live in the same w...  SG.LOC.LIVE.EQ   NaN
# 3  A woman can get a job in the same way as a man...  SG.GET.JOBS.EQ   NaN
# 4  A woman can obtain a judgment of divorce in th...  SG.OBT.DVRC.EQ   NaN
#
#    1961  1962  1963  1964  1965     ...       2012  2013  2014  2015  2016  \
# 0   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN     ...        NaN   NaN   NaN   NaN   NaN
# ...

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164112 entries, 0 to 164111
# Data columns (total 66 columns):
# Country Name      164112 non-null object
# Country Code      164112 non-null object
# Indicator Name    164112 non-null object
# Indicator Code    164112 non-null object
# 1960              8207 non-null float64
# 1961              8208 non-null float64
# 1962              8966 non-null float64
# 1963              8376 non-null float64
# 1964              8400 non-null float64
# 1965              8476 non-null float64
# 1966              8605 non-null float64
# 1967              9203 non-null float64
# 1968              8633 non-null float64
# 1969              8697 non-null float64
# 1970              17971 non-null float64
# 1971              19723 non-null float64
# 1972              20248 non-null float64
# 1973              19649 non-null float64
# 1974              19692 non-null float64
# 1975              20781 non-null float64
# ...

# %%
#Converting the horizontal dataset into vertical format
idx = ['Country Name','Country Code','Indicator Name','Indicator Code']

multi_index_df = stats.set_index(idx)
multi_index_df
# Out:
#                                                                                                          1960  \
# Country Name Country Code Indicator Name                                     Indicator Code
# Arab World   ARB          A woman can apply for a passport in the same wa... SG.APL.PSPT.EQ               NaN
#                           A woman can be head of household in the same wa... SG.HLD.HEAD.EQ               NaN
#                           A woman can choose where to live in the same wa... SG.LOC.LIVE.EQ               NaN
#                           A woman can get a job in the same way as a man ... SG.GET.JOBS.EQ               NaN
#                           A woman can obtain a judgment of divorce in the... SG.OBT.DVRC.EQ               NaN
#                           A woman can open a bank account in the same way... SG.OPN.BANK.EQ               NaN
#                           A woman can register a business in the same way... SG.BUS.REGT.EQ               NaN
# ...

# %%
stacked_df = multi_index_df.stack(dropna=False)
stacked_df
# Out:
# Country Name  Country Code  Indicator Name                                                           Indicator Code
# Arab World    ARB           A woman can apply for a passport in the same way as a man (1=yes; 0=no)  SG.APL.PSPT.EQ    1960                NaN
#                                                                                                                        1961                NaN
#                                                                                                                        1962                NaN
#                                                                                                                        1963                NaN
#                                                                                                                        1964                NaN
#                                                                                                                        1965                NaN
# ...

# %%
long_df = stacked_df.reset_index()
long_df.rename({'level_4':'Year', 0:'Indicator Value'}, axis=1, inplace=True)
long_df
# Out:
#          Country Name Country Code  \
# 0          Arab World          ARB
# 1          Arab World          ARB
# 2          Arab World          ARB
# 3          Arab World          ARB
# 4          Arab World          ARB
# 5          Arab World          ARB
# 6          Arab World          ARB
# 7          Arab World          ARB
# 8          Arab World          ARB
# 9          Arab World          ARB
# 10         Arab World          ARB
# 11         Arab World          ARB
# 12         Arab World          ARB
# 13         Arab World          ARB
# 14         Arab World          ARB
# 15         Arab World          ARB
# 16         Arab World          ARB
# 17         Arab World          ARB
# 18         Arab World          ARB
# 19         Arab World          ARB
# 20         Arab World          ARB
# 21         Arab World          ARB
# 22         Arab World          ARB
# 23         Arab World          ARB
# 24         Arab World          ARB
# ...

# %%
long_df['Year'].unique()
# Out:
# array(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65'],
#       dtype=object)

# %%
long_df = long_df.loc[long_df['Year']!='Unnamed: 65']
long_df['Year'] = long_df['Year'].astype(int)
# Out:
# C:\Users\Sinchita Siddiquee\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
stats_df = long_df.drop('Indicator Code', axis=1)
stats_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Year  Indicator Value
# 0  A woman can apply for a passport in the same w...  1960              NaN
# 1  A woman can apply for a passport in the same w...  1961              NaN
# 2  A woman can apply for a passport in the same w...  1962              NaN
# 3  A woman can apply for a passport in the same w...  1963              NaN
# 4  A woman can apply for a passport in the same w...  1964              NaN

# %%
stats_df = stats_df[stats_df['Year']>=1980]
stats_df
# Out:
#          Country Name Country Code  \
# 20         Arab World          ARB
# 21         Arab World          ARB
# 22         Arab World          ARB
# 23         Arab World          ARB
# 24         Arab World          ARB
# 25         Arab World          ARB
# 26         Arab World          ARB
# 27         Arab World          ARB
# 28         Arab World          ARB
# 29         Arab World          ARB
# 30         Arab World          ARB
# 31         Arab World          ARB
# 32         Arab World          ARB
# 33         Arab World          ARB
# 34         Arab World          ARB
# 35         Arab World          ARB
# 36         Arab World          ARB
# 37         Arab World          ARB
# 38         Arab World          ARB
# 39         Arab World          ARB
# 40         Arab World          ARB
# 41         Arab World          ARB
# 42         Arab World          ARB
# 43         Arab World          ARB
# 44         Arab World          ARB
# ...

# %%
join_df = pd.merge(stats_df,country,on='Country Code',how='left')
join_df = join_df[['Country Code','Country Name','Region','Income Group','Indicator Name','Year','Indicator Value']]
join_df = join_df[join_df['Region'].notnull()]
join_df
# Out:
#         Country Code Country Name              Region         Income Group  \
# 1176864          AFG  Afghanistan          South Asia           Low income
# 1176865          AFG  Afghanistan          South Asia           Low income
# 1176866          AFG  Afghanistan          South Asia           Low income
# 1176867          AFG  Afghanistan          South Asia           Low income
# 1176868          AFG  Afghanistan          South Asia           Low income
# 1176869          AFG  Afghanistan          South Asia           Low income
# 1176870          AFG  Afghanistan          South Asia           Low income
# 1176871          AFG  Afghanistan          South Asia           Low income
# 1176872          AFG  Afghanistan          South Asia           Low income
# 1176873          AFG  Afghanistan          South Asia           Low income
# 1176874          AFG  Afghanistan          South Asia           Low income
# ...

# %%
#csv_test = join_df[join_df['Indicator Name']=='Expected Years of School']
#csv_test.to_csv(r'C:\Users\Sinchita Siddiquee\Desktop\Sinchita Siddiquee\Personal Projects\World Bank Gender Statistics\csv_test.csv', index=False, header=True)

# %%
null_check = {}

for i in join_df['Indicator Name'].unique():
    df = join_df[join_df['Indicator Name']==i]
    total_cnt = df['Indicator Value'].size
    null_cnt = df['Indicator Value'].isnull().sum()
    non_null_cnt = total_cnt - null_cnt
    cnt_list = [total_cnt, null_cnt, non_null_cnt]
    null_check[i] = cnt_list
    
null_check
# Out:
# {'A woman can apply for a passport in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can be head of household in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can choose where to live in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can get a job in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can obtain a judgment of divorce in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can open a bank account in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can register a business in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can sign a contract in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
#  'A woman can travel outside her home in the same way as a man (1=yes; 0=no)': [8897,
#   1337,
#   7560],
# ...

# %%
#null_df = pd.DataFrame(list(null_check.items()),columns = ['Indicator Name','Count'])
list(null_check.items())
# Out:
# [('A woman can apply for a passport in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can be head of household in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can choose where to live in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can get a job in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can obtain a judgment of divorce in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can open a bank account in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can register a business in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can sign a contract in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
#  ('A woman can travel outside her home in the same way as a man (1=yes; 0=no)',
#   [8897, 1337, 7560]),
# ...

# %%
df = join_df[join_df['Indicator Name']=='Expected Years of School']
null_cnt = df['Indicator Value'].isnull().sum()
total_cnt = df['Indicator Value'].size
total_cnt
# Out:
# 8897

# %%
null_cnt
# Out:
# 8273

# %%
join_df = join_df[(join_df['Indicator Name']=="Expected years of schooling, female")|
        (join_df['Indicator Name']=="Expected years of schooling, male")|
        (join_df['Indicator Name']=="Female share of employment in senior and middle management (%)")|
        (join_df['Indicator Name']=="GDP per capita (Current US$)")|
        (join_df['Indicator Name']=="Government expenditure on education, total (% of GDP)")|
        (join_df['Indicator Name']=="Gross graduation ratio, primary, female (%)")|
        (join_df['Indicator Name']=="Gross graduation ratio, primary, male (%)")|
        (join_df['Indicator Name']=="Gross graduation ratio, tertiary, female (%)")|
        (join_df['Indicator Name']=="Gross graduation ratio, tertiary, male (%)")|
        (join_df['Indicator Name']=="Labor force, female (% of total labor force)")|
        (join_df['Indicator Name']=="Primary completion rate, female (% of relevant age group)")|
        (join_df['Indicator Name']=="Primary completion rate, male (% of relevant age group)")|
        (join_df['Indicator Name']=="Proportion of seats held by women in national parliaments (%)")|
        (join_df['Indicator Name']=="Self-employed, female (% of female employment) (modeled ILO estimate)")|
        (join_df['Indicator Name']=="Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)")
       ]

# %%
join_df['Indicator Name'].unique()

# %%
ind_pivot = join_df.pivot_table('Indicator Value', ['Country Code','Country Name','Region','Income Group','Year'], 'Indicator Name')
ind_pivot.head()

# %%
ind_pivot.reset_index(inplace=True)
ind_pivot

# %%
ind_pivot.rename_axis(None, axis=1, inplace=True)
ind_pivot

# %%
ind_pivot.rename({
'Expected years of schooling, female' : 'Expected Years of Schooling (Female)',
'Expected years of schooling, male' : 'Expected Years of Schooling (Male)',
'Female share of employment in senior and middle management (%)' : 'Share in Senior Management (Female, %)',
'Female share of graduates from Science, Technology, Engineering and Mathematics (STEM) programmes, tertiary (%)' : 'Share of STEM Graduates (Female, %)',
'GDP per capita (Current US$)' : 'GDP Per Capita (Current US$)',
'Government expenditure on education, total (% of GDP)' : 'Govement Expenditure on Education (% of GDP)',
'Gross graduation ratio, primary, female (%)' : 'Gross Primary Graduation Ratio (Female, %)',
'Gross graduation ratio, primary, male (%)' : 'Gross Primary Graduation Ratio (Male, %)',
'Gross graduation ratio, tertiary, female (%)' : 'Gross Tertiary Graduation Ratio (Female, %)',
'Gross graduation ratio, tertiary, male (%)' : 'Gross Tertiary Graduation Ratio (Male, %)',
'Labor force, female (% of total labor force)' : 'Share of Labor Force (Female, %)',
'Primary completion rate, female (% of relevant age group)' : 'Primary Completion Rate (Female, %)',
'Primary completion rate, male (% of relevant age group)' : 'Primary Completion Rate (Male, %)',
'Proportion of seats held by women in national parliaments (%)' : 'Share of Seats in National Parliament (Female, %)',
'Ratio of female to male labor force participation rate (%) (modeled ILO estimate)' : 'Female To Male Labor Force Participation (%)'
}, axis=1, inplace=True)

# %%
ind_pivot

# %%
#ind_pivot.to_csv (r'C:\Users\Sinchita Siddiquee\Desktop\Sinchita Siddiquee\Personal Projects\World Bank Gender Statistics\ind_pivot_extract2.csv', index = False, header=True)

# %%
ind_pivot.describe()

# %%
ind_pivot.info()

# %%
ind_pivot['Year'] = ind_pivot['Year'].astype(int)
ind_pivot = ind_pivot.loc[ind_pivot['Year']>=1999]
ind_pivot

# %%
ind_pivot.info()
